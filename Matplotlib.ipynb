# %% [markdown]
# ## Matplotlib

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
plt.plot()
# Out:
# []

# %%
plt.show()

# %%
x=[1,3,5,7]
y=[0,2,4,6]
plt.plot(x,y);

# %% [markdown]
# # Creating matplotlib plots and figure

# %%
#1st method
fig=plt.figure()
ax=fig.add_subplot()
plt.show()

# %%
#2nd method
fig=plt.figure()
ax=fig.add_axes([1,1,1,1])
ax.plot(x,y)
plt.show()

# %%
#3rd method
fig,ax=plt.subplots()
ax.plot(x,y)

# %%
#creating a simple plot
# %matplotlib inline
import matplotlib.pyplot as plt
#1.prepare data
x=[1,2,3,4]
y=[11,22,33,44]
#2.setup plot
fig,ax=plt.subplots(figsize=(5,10))
#3.plot data
ax.plot(x,y)
# 4.cutomize plot
ax.set(title="Simple Plot",xlabel="x-axis",ylabel="y-axis",)
#5.Save and store the plot
fig.savefig("images/sample-plot.png")

# %%
#Making figures with numpy array
import numpy as np

# %%
x=np.linspace(0,10,100)
x[:20],x.shape
# Out:
# (array([0.        , 0.1010101 , 0.2020202 , 0.3030303 , 0.4040404 ,
#         0.50505051, 0.60606061, 0.70707071, 0.80808081, 0.90909091,
#         1.01010101, 1.11111111, 1.21212121, 1.31313131, 1.41414141,
#         1.51515152, 1.61616162, 1.71717172, 1.81818182, 1.91919192]),
#  (100,))

# %%
#Plot the data and create a line plot
fig,ax=plt.subplots()
ax.plot(x,x**2); 
#this is a line plot

# %%
#Use same data and make a scatter for creating a scatterplot
fig,ax=plt.subplots()
ax.scatter(x,np.exp(x));

# %%
#Another scatter plt
fig,ax=plt.subplots()
ax.scatter(x,np.cos(x));

# %%
#Make a plot from dictionary
med_prices={"Minidoxiline":349,"Paracetamol":23,"Relif Spray":120}
fig,ax=plt.subplots()
ax.bar(med_prices.keys(),med_prices.values())
ax.set(title="Med Prices",xlabel="Medicines",ylabel="MRP");

# %%
#Creating a plot from barh(for viewing a horizontal bar)
# %matplotlib inline
import matplotlib.pyplot as plt
fig,ax=plt.subplots()
ax.barh(list(med_prices.keys()),list(med_prices.values()))
plt.show()

# %%
#Make some data
x=np.random.randn(1000)
#Plot a histogram
fig,ax=plt.subplots()
ax.hist(x)
# Out:
# (array([  6.,  31.,  83., 145., 249., 223., 166.,  76.,  13.,   8.]),
#  array([-3.14669664e+00, -2.51710769e+00, -1.88751874e+00, -1.25792979e+00,
#         -6.28340834e-01,  1.24811871e-03,  6.30837071e-01,  1.26042602e+00,
#          1.89001498e+00,  2.51960393e+00,  3.14919288e+00]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# #Two options for subplots

# %%
#Subplot opt1:
fig,((ax1,ax2),(ax3,ax4))=plt.subplots(nrows=2,ncols=2,figsize=(10,5))
#Plot the data to each different axis
ax1.plot(x,x/2);
ax2.scatter(np.random.random(10),np.random.random(10));
ax3.bar(med_prices.keys(),med_prices.values());
ax4.hist(np.random.random(200));

# %%
#Subplots opt2:
fig,ax=plt.subplots(nrows=2,ncols=2,figsize=(10,5))
#plot to each different index
ax[0,0].plot(x,x/2);
ax[0,1].scatter(np.random.random(10),np.random.random(10));
ax[1,0].bar(med_prices.keys(),med_prices.values());
ax[1,1].hist(np.random.randn(200));

# %%
a1=np.random.randn(420)
a1[:20]
# Out:
# array([-0.69731849, -0.70220789, -0.12008341,  0.92852359, -0.26586671,
#         1.32731669,  0.06672069, -1.10778422,  2.57166322, -1.11951707,
#        -0.74250749, -0.93383636, -0.06617051,  0.06478123,  0.24239668,
#        -1.90552501, -0.30027458, -1.42097594,  0.68787192,  0.02090657])

# %%
#1.line plot
fig,ax=plt.subplots()
ax.plot(a1,a1);

# %%
#2.Scatter plot
fig,ax=plt.subplots()
ax.scatter(a1,a1//2)

# %%
#3.bar plot
y=np.random.randn(220)
fig,ax=plt.subplots()
ax.bar(x,x//2)
# Out:
# <BarContainer object of 1000 artists>

# %%
#4.Histogram
fig,ax=plt.subplots()
ax.hist(y)
# Out:
# (array([11., 17., 30., 39., 60., 27., 23.,  9.,  2.,  2.]),
#  array([-2.18750683, -1.68647175, -1.18543667, -0.68440158, -0.1833665 ,
#          0.31766859,  0.81870367,  1.31973876,  1.82077384,  2.32180892,
#          2.82284401]),
#  <BarContainer object of 10 artists>)

# %%
#5.Subplots
#Options 1:
fig,((ax1,ax2),(ax3,ax4))=plt.subplots(nrows=2,ncols=2,figsize=(10,5))
ax1.plot(x,x**2)
ax2.scatter(x,x/2)
ax3.bar(med_prices.keys(),med_prices.values())
ax4.hist(y)
# Out:
# (array([11., 17., 30., 39., 60., 27., 23.,  9.,  2.,  2.]),
#  array([-2.18750683, -1.68647175, -1.18543667, -0.68440158, -0.1833665 ,
#          0.31766859,  0.81870367,  1.31973876,  1.82077384,  2.32180892,
#          2.82284401]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# # Plotting from pandas dataframe

# %%
import pandas as pd
import numpy as np

# %%
car_sales=pd.read_csv("car-sales.csv")
car_sales
# Out:
#    Unnamed: 0    Make Colour  Odometer (KM)  Doors       Price
# 0           0  Toyota  White         150043      4   $4,000.00
# 1           1   Honda    Red          87899      4   $5,000.00
# 2           2  Toyota   Blue          32549      3   $7,000.00
# 3           3     BMW  Black          11179      5  $22,000.00
# 4           4  Nissan  White         213095      4   $3,500.00
# 5           5  Toyota  Green          99213      4   $4,500.00
# 6           6   Honda   Blue          45698      4   $7,500.00
# 7           7   Honda   Blue          54738      4   $7,000.00
# 8           8  Toyota  White          60000      4   $6,250.00
# 9           9  Nissan  White          31600      4   $9,700.00

# %%
np.random.seed(123456)

ts = pd.Series(np.random.randn(1000), index=pd.date_range("23/5/2000", periods=1000))

ts = ts.cumsum()

ts.plot();

# %%
car_sales=pd.read_csv('car-sales.csv')
car_sales["Price"]=car_sales["Price"].str.replace(r'[\$\,\.]','',regex=True)
car_sales
# Out:
#    Unnamed: 0    Make Colour  Odometer (KM)  Doors    Price
# 0           0  Toyota  White         150043      4   400000
# 1           1   Honda    Red          87899      4   500000
# 2           2  Toyota   Blue          32549      3   700000
# 3           3     BMW  Black          11179      5  2200000
# 4           4  Nissan  White         213095      4   350000
# 5           5  Toyota  Green          99213      4   450000
# 6           6   Honda   Blue          45698      4   750000
# 7           7   Honda   Blue          54738      4   700000
# 8           8  Toyota  White          60000      4   625000
# 9           9  Nissan  White          31600      4   970000

# %%
car_sales["Price"].dtype
# Out:
# dtype('O')

# %%
type(car_sales["Price"][0])
# Out:
# str

# %%
car_sales["Total Sales"]=car_sales["Price"].astype(int).cumsum()
car_sales
# Out:
#    Unnamed: 0    Make Colour  Odometer (KM)  Doors    Price  Total Sales
# 0           0  Toyota  White         150043      4   400000       400000
# 1           1   Honda    Red          87899      4   500000       900000
# 2           2  Toyota   Blue          32549      3   700000      1600000
# 3           3     BMW  Black          11179      5  2200000      3800000
# 4           4  Nissan  White         213095      4   350000      4150000
# 5           5  Toyota  Green          99213      4   450000      4600000
# 6           6   Honda   Blue          45698      4   750000      5350000
# 7           7   Honda   Blue          54738      4   700000      6050000
# 8           8  Toyota  White          60000      4   625000      6675000
# 9           9  Nissan  White          31600      4   970000      7645000

# %%
car_sales["Sales Date"]=pd.date_range("23/5/2024",periods=len(car_sales))
car_sales
# Out:
#    Unnamed: 0    Make Colour  Odometer (KM)  Doors    Price  Total Sales  \
# 0           0  Toyota  White         150043      4   400000       400000
# 1           1   Honda    Red          87899      4   500000       900000
# 2           2  Toyota   Blue          32549      3   700000      1600000
# 3           3     BMW  Black          11179      5  2200000      3800000
# 4           4  Nissan  White         213095      4   350000      4150000
# 5           5  Toyota  Green          99213      4   450000      4600000
# 6           6   Honda   Blue          45698      4   750000      5350000
# 7           7   Honda   Blue          54738      4   700000      6050000
# 8           8  Toyota  White          60000      4   625000      6675000
# 9           9  Nissan  White          31600      4   970000      7645000
#
#   Sales Date
# 0 2024-05-23
# 1 2024-05-24
# 2 2024-05-25
# 3 2024-05-26
# 4 2024-05-27
# 5 2024-05-28
# 6 2024-05-29
# 7 2024-05-30
# 8 2024-05-31
# 9 2024-06-01

# %%
car_sales.plot(x="Sales Date",y="Total Sales")
# Out:
# <Axes: xlabel='Sales Date'>

# %%
car_sales["Price"]=car_sales["Price"].astype(int)

# %%
car_sales.plot(x="Odometer (KM)",y="Price",kind="scatter")
# Out:
# <Axes: xlabel='Odometer (KM)', ylabel='Price'>

# %%
car_sales.plot(x="Colour",y="Price",kind="bar")
# Out:
# <Axes: xlabel='Colour'>

# %%
car_sales["Odometer (KM)"].plot.hist();

# %%
heart_disease=pd.read_csv("heart-disease.csv")
heart_disease
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
heart_disease.dtypes
# Out:
# age           int64
# sex           int64
# cp            int64
# trestbps      int64
# chol          int64
# fbs           int64
# restecg       int64
# thalach       int64
# exang         int64
# oldpeak     float64
# slope         int64
# ca            int64
# thal          int64
# target        int64
# dtype: object

# %%
# male_cnt=0
# female_cnt=0
# for i in heart_disease.sex:
#     if i==0:
#         male_cnt+=1
#     else:
#         female_cnt+=1
# print(male_cnt,female_cnt)
# Sex=[male_cnt,female_cnt]
heart_disease.plot(x="trestbps",y="sex",kind="bar")
# Out:
# <Axes: xlabel='trestbps'>

# %%
heart_disease["age"].plot.hist(bins=20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
 heart_disease.plot.hist(figsize=(10,30),subplots=True)
# Out:
# array([<Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>,
#        <Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>,
#        <Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>,
#        <Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>,
#        <Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>,
#        <Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>,
#        <Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>],
#       dtype=object)

# %%
over_50=heart_disease[heart_disease["age"]>50]

# %%
#pyplot method
over_50.plot(kind="scatter",x="age",y="chol",c="target")
# Out:
# <Axes: xlabel='age', ylabel='chol'>

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
fig,ax=plt.subplots(figsize=(10,6))
over_50.plot(kind="scatter",x="age",y="chol",c="target",ax=ax);
ax.set_xlim([45,100])
# Out:
# (45.0, 100.0)

# %%
#OO method from scratch
fig,ax=plt.subplots(figsize=(10,6))
#Plotting the data
scatter=ax.scatter(x=over_50["age"],y=over_50["chol"],c=over_50["target"])
ax.set(title="Heart Disease and Cholestrol Levels",xlabel="Age",ylabel="Cholestrol")
ax.legend(*scatter.legend_elements(),title="Target")
ax.axhline(over_50["chol"].mean(),linestyle="--")

# %%
#Subplot of chol,age and thalach
fig,(ax0,ax1)=plt.subplots(nrows=2,ncols=1,figsize=(10,10),sharex=True)
scatter=ax0.scatter(x=over_50["age"],y=over_50["chol"],c=over_50["target"],cmap="winter")
ax0.set(title="Heart Disease and Cholestrol Levels",ylabel="Cholestrol")
ax0.legend(*scatter.legend_elements(),title="Target")
ax0.axhline(over_50["chol"].mean(),linestyle="--")

scatter=ax1.scatter(x=over_50["age"],y=over_50["thalach"],c=over_50["target"])
ax1.set(title="Heart Disease and Max Heart Rate Levels",xlabel="Age",ylabel="thalcol")
ax1.legend(*scatter.legend_elements(),title="Target")
ax1.axhline(over_50["thalach"].mean(),linestyle="--")

fig.suptitle("Heart Disease Analysis w.r.t. Age",fontsize=10,fontweight="bold")
# Out:
# Text(0.5, 0.98, 'Heart Disease Analysis w.r.t. Age')

# %% [markdown]
# ## Customizing Matplotlib plots and getting stylish

# %%
#Different styles available:
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use('seaborn-v0_8')

# %%
car_sales["Price"].plot()
# Out:
# <Axes: >

# %%
car_sales.plot(x="Odometer (KM)",y="Price",kind="scatter")
# Out:
# <Axes: xlabel='Odometer (KM)', ylabel='Price'>

# %%
x=np.random.randn(10,4)
df=pd.DataFrame(x,columns=['a','b','c','d'])
df
# Out:
#           a         b         c         d
# 0 -0.335613  0.948985  0.599997 -0.337023
# 1 -0.595359 -0.875338  1.222503  0.873108
# 2 -0.589810  2.261936 -0.388312 -0.120132
# 3  0.452181 -0.303344  0.648378 -1.004239
# 4  1.197946  0.765543 -0.423806  1.041571
# 5 -0.786641 -0.393609 -0.171092  1.786173
# 6 -0.575189  0.820750 -1.256530 -0.642246
# 7  0.236892 -0.466867 -1.382653 -0.369422
# 8  0.858644 -0.851236  1.058006 -0.080372
# 9 -1.268121  1.561967  0.816983  1.965656

# %%
ax=df.plot(kind="bar")
type(ax)
# Out:
# matplotlib.axes._axes.Axes

# %%
#Customize plot with the set method
ax=df.plot(kind="bar")
ax.set(title="Random Number Bar Graph from df",xlabel="Row Number",ylabel="Random Numbers")
ax.legend().set_visible(True)

# %%
#More Customizing the plot
#Subplot of chol,age and thalach
fig,(ax0,ax1)=plt.subplots(nrows=2,ncols=1,figsize=(10,10),sharex=True)
scatter=ax0.scatter(x=over_50["age"],y=over_50["chol"],c=over_50["target"],cmap="winter")
ax0.set(title="Heart Disease and Cholestrol Levels",ylabel="Cholestrol")
ax0.legend(*scatter.legend_elements(),title="Target")
ax0.axhline(over_50["chol"].mean(),linestyle="--")
ax0.set_xlim([50,90])

scatter=ax1.scatter(x=over_50["age"],y=over_50["thalach"],c=over_50["target"],cmap="summer")
ax1.set(title="Heart Disease and Max Heart Rate Levels",xlabel="Age",ylabel="thalcol")
ax1.legend(*scatter.legend_elements(),title="Target")
ax1.axhline(over_50["thalach"].mean(),linestyle="--")
ax1.set_ylim([40,130])

fig.suptitle("Heart Disease Analysis w.r.t. Age",fontsize=10,fontweight="bold")
# Out:
# Text(0.5, 0.98, 'Heart Disease Analysis w.r.t. Age')

# %%
fig

# %%
fig.savefig("heart-disease-analysis.png")

# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
heart_disease=pd.read_csv("heart-disease.csv")
heart_disease
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
fig,ax=plt.subplots(figsize=(10,6))
bar=ax.bar(heart_disease["thalach"],heart_disease["oldpeak"])
plt.show()

# %%
fig,ax=plt.subplots()
ax.hist(heart_disease["trestbps"])
plt.show()

# %%
fig,(ax0,ax1)=plt.subplots(nrows=2,ncols=1,figsize=(10,10),sharex=True)

scatter=ax0.scatter(x=heart_disease["thalach"],y=heart_disease["oldpeak"],c=heart_disease["sex"],cmap="winter")
ax0.set(title="thalach level vs oldpeak level",ylabel="oldpeak")
ax0.legend(*scatter.legend_elements(),title="sex",)
ax0.axhline(heart_disease["oldpeak"].mean(),linestyle="--")

bar=ax1.bar(heart_disease["thalach"],heart_disease["thal"])
ax1.set(title="thal level vs thalach level",ylabel="thal",xlabel="thalach level")
ax1.legend(*scatter.legend_elements(),title="sex")
ax1.axhline(heart_disease["thal"].mean(),linestyle="--")

# %%
fig.savefig("thalach level vs thal level,oldpeak lebel.png")
